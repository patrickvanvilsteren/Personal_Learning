# %%
# import Python modules 

import os
import json

from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# load the .env file
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with debugging

openai_api_key = os.getenv("OPENAI_API_KEY")
anthropic_api_key = os.getenv("ANTHROPIC_API_KEY")

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-

# %%
# Let the LLM create a question

request = "Please come up with a question about space exploration. This question is asked to different LLM's to evaluate there intelligence."
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

messages

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)

competitors = []
answers = []
messages = [{"role": "user", "content": question }]
# Out:
# Design a prioritized 20-year strategy for human and robotic space exploration of the Moon and Mars using technologies achievable within the next decade—specifying mission types, transportation and habitat architectures, required technology development milestones, launch cadence and estimated costs, scientific objectives and measurements, risk assessments with mitigation plans, international and commercial partnership roles, and objective success criteria for each phase?

# %%
model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Below is a concise, prioritized 20-year strategy to achieve sustained human and robotic exploration of the Moon and Mars using technologies realistically achievable within the next decade. The plan emphasizes a Moon-first approach to de-risk long-duration human spaceflight, develop ISRU and surface infrastructure, and progressively mature the capability and science to enable a credible crewed mission to Mars in the later part of the period.
#
# Executive goals and guiding principles
# - Aim: Establish sustainable, multi-year human presence on the Moon (surface and cislunar operations) and enable a crewed Mars mission within ~20 years, with early robotic precursors and shared international/commercial responsibility.
# - Principles:
#   - Incremental capability maturation with rigorous testing before committing to high-risk missions.
#   - Reuse, standardization, and modular architectures to reduce cost and risk.
#   - ISRU (in-situ resource utilization) and in-space power/propulsion advances to reduce mass and propellant needs.
#   - Strong international collaboration and commercial participation, with clear governance, data-sharing, and safety standards.
#   - Comprehensive risk management, including radiation, life support viability, EVA safety, contamination controls, and supply chain resilience.
#
# Phase 0 (0–5 years; 2026–2030): Technology maturation, robotic precursors, and early human-in-the-loop testing
# Objectives
# - Demonstrate and mature essential enabling technologies (ISRU concepts, in-space power, radiation shielding, closed-loop life support, and surface mobility).
# - Validate mission architectures (cislunar gateway concept, lunar surface habitats, and logistics for crewed operations).
# - Collect high-priority lunar science data and test operations for a sustainable lunar outpost.
#
# Mission types and architectures
# - Robotic precursor missions to the Moon:
#   - Lander rovers and stationary landers to characterize permanently shadowed regions (PSRs), map volatiles, and deploy seismic, radar, and dust/plume sensors.
#   - ISRU demonstrations: water ice extraction, electrolysis, oxygen generation, and regolith processing prototypes.
# - Human-in-the-loop demonstrations in cis-lunar space:
#   - Short-duration crewed tests aboard a gateway-like platform or in free space around the Moon (26–90 days) to validate life support, EVA suits, suit cooling, and habitat thermal control.
# - Lunar surface habitat concept validation:
#   - Ground-based and in-space demonstrations of modular, radiation-shielded, mixed-material habitats (inflatable modules + regolith shielding concepts).
# - Scientific objectives and measurements:
#   - Water/ice abundance and distribution in PSRs; hydrogen/oxygen production rates; surface radiation environment (quality factor, dose per mission day); regolith mechanical properties; geology and stratigraphy of mare/highlands; exosphere composition.
#   - Measurements: in-situ resource yields, water ice stability analyses, radiation dose logs, surface temperature, seismic/ground-penetrating radar data, and sample caches for return or analysis in-Lab.
# - Transportation and habitat architectures:
#   - Continued use and maturation of SLS/Orion for crewed US launches; commercial lunar landers for cargo; Starship/other heavy-lift capable vehicles for cargo and potentially crewed landings if safety, redundancy, and certification criteria are met; lunar gateway module concepts; surface habitat prototypes with modular docking interfaces.
# - Milestones and technology developments:
#   - ISRU demonstration on the Moon and/or in cislunar environment.
#   - Closed-loop life-support demonstrations (potable water recovery, air revitalization, waste processing) at TRL 6–7.
#   - Radiation shielding demonstrations using water/ice and regolith-backed configurations.
#   - Autonomous landing, rendezvous, docking, EVA, and habitat-assembly demonstrations.
# - Launch cadence and estimated costs:
#   - Robotic lunar precursor missions: 2–4 per year (cargo and small landers) through the decade.
#   - Crew-test missions: 1–2 short-duration flights to a gateway or near-Moon platform to validate life support and EVA protocols.
#   - Estimated costs: roughly in the tens of billions over the phase (order-of-magnitude guidance: US and partner investments ≈ $15–30B; international and commercial contributions add substantial value). Costs vary with international cost-sharing and commercial roles.
# - Risk assessment and mitigation:
#   - Radiation exposure during deep-space operations and long lunar stays: mitigation via increased shielding (water/ice, regolith), scheduling solar quiet periods, and mission timing planning.
#   - Life-support reliability: redundant subsystems, rapid repair capability, and pre-placed spare modules; robust recycling loops.
#   - EVA safety: advanced spacesuit design, EVA procedures, autonomous rescue capability, and emergency return options.
#   - Contamination controls: planetary protection protocols for Moon; strict cleanroom and containment for any unknown assays.
#   - Schedule risk and supply chain: early qualification of critical subsystems; parallel development paths to avoid single-point failures.
# - International and commercial partnerships:
#   - Strengthen Artemis-like frameworks; extend collaboration with ESA, JAXA, CSA, Roscosmos (subject to geopolitical conditions); enable CLPS-like commercial lunar landers and habitat modules; establish data-sharing and joint science programs; initiate public-private partnerships for ISRU demonstrations.
# - Objective success criteria:
#   - Demonstrated reliable ISRU rates and water/isotope measurements at PSR or regolith test sites.
#   - Successful closed-loop life support demonstrations for at least 30–60 days in a space environment.
#   - Radiation shielding performance ensuring crew dose limits within acceptable thresholds for planned durations.
#   - Safe robotic landing, deployment, and sample handling on the Moon; successful EVA operations with fault-tolerant suits and systems.
#   - Clear, actionable roadmaps for a crewed lunar mission with defined vehicle interfaces, habitat modules, and logistics.
#
# Phase 1 (5–10 years; 2030–2035): Sustainable lunar outpost development and Mars precursor groundwork
# Objectives
# - Establish a sustainable, modular lunar surface outpost with intermittent crew presence and robust logistics.
# - Mature Mars transit readiness via in-space testing, ISRU, and trajectory studies; demonstrate interplanetary logistics and sample caching for Mars missions.
# - Prove large-scale cross-continental collaboration and private sector supply chains for lunar operations.
#
# Mission types and architectures
# - Lunar outpost expansion:
#   - Reusable or semi-reusable logistics flights delivering habitat modules, power systems (arrays and/or compact nuclear), life-support subsystems, rovers, and mining/ISRU equipment.
#   - Longer-duration lunar surface missions (30–90 days) to test habitability, maintenance, crew workflows, and surface operations at a self-sustaining cadence.
# - Mars precursor activities:
#   - Robotic missions to Mars orbit or surface to test entry, descent, and landing (EDL) for different terrains; cached surface samples or pre-deployed assets (propellant production seeds) to support a future crewed landing.
#   - Demonstrations of long-duration life support, water recycling, and food production in closed environments, mimicking a Mars-departure scenario.
# - Scientific objectives and measurements:
#   - Lunar geology, regolith properties under long-term exposure, volcanic history, polar volatiles distribution, and solar wind-ice interactions.
#   - Mars transit knowledge: scalable deep-space propulsion concepts (chemical, staged or electric), propulsion efficiency, and long-duration life support performance; planning for an eventual Earth-return sample cache.
# - Transportation and habitat architectures:
#   - Lunar: expanded gateway-to-surface operations with modular surface habitats, surface rovers, ISRU processors, and robust power generation (solar arrays with enhanced energy storage or small modular reactors depending on policy and safety standards).
#   - Mars prep: cargo missions carrying ISRU demonstration equipment, Mars-appropriate life support testbeds in cislunar or lunar analog environments, and propulsion testing hardware in space.
# - Milestones and technology developments:
#   - Operational milestone: sustained 3–6 month stays on the Moon with reliable logistics and habitat maintenance.
#   - ISRU: production of oxygen and viable propellant precursors on the Moon using indigenous resources; demonstration of regolith processing for building materials.
#   - Mars precursor: validated EDL techniques and surface operations for future crewed milestones; more advanced crewed habitat life support tests in deep-space-like environments.
# - Launch cadence and estimated costs:
#   - Lunar: 2–4 crewed or habitability flights per year, plus ongoing cargo deliveries; 3–6 robotic precursor missions annually.
#   - Mars precursor: annual or near-annual robotic campaigns; periodic cargo/propellant delivery missions to support any future crewed Mars operations.
#   - Estimated phase costs: tens of billions USD, with major contributions from international partners and commercial ventures; total program phase cost could be in the range of $40–80B depending on scale and partnerships.
# - Risk assessment and mitigation:
#   - Habitability and life-support risk: multiple redundancy, modular spares, autonomous maintenance capabilities, and remote diagnostics.
#   - ISRU and propellant reliability: staged demonstrations with fallback supply lines; verification in cislunar early tests.
#   - Radiation risk during longer lunar stays and deep-space transit: design-based shielding, mission timing, and exposure monitoring; mission abort protocols.
#   - Schedule risk: parallel development paths for critical subsystems; early qualification of key components; international partner contingency fees.
# - International and commercial partnerships:
#   - Increased participation by ESA, JAXA, CSA, and other partners for gateway expansions, surface habitat modules, life-support tech, and ISRU processes.
#   - Strong private-sector role in lunar logistics, habitat manufacturing, and ISRU equipment, with procurement models emphasizing competition and standard interfaces for interoperability.
# - Objective success criteria:
#   - Achieve multiple 1–3 month lunar surface missions with self-sufficiency in basic food/waste recycling and regenerative life support loops.
#   - Demonstrate reliable lunar ISRU-derived oxygen and propellants at scale with waste-safe processing.
#   - Validate Mars-trajectory iteration and EDL techniques through robotic missions and tests, with a credible plan for a crewed mission to Mars in the following phase.
#   - Established, sustained international and commercial partnerships with shared governance and data standards.
#
# Phase 2 (10–15 years; 2035–2040): Mars readiness milestone track and expanded Moon operations
# Objectives
# - Move toward a credible, repeatable Mars mission architecture with validated deep-space propulsion, long-duration life support, and in-space habitat integration.
# - Build on the lunar outpost to deliver a more robust, long-duration, high-activity lunar capability that can support Mars mission rehearsals.
# - Advance science objectives on Moon and Mars to refine landing sites, resource availability, and mission risk mitigations.
#
# Mission types and architectures
# - Mars readiness track:
#   - Crewed long-duration transits (targeting 9–12 months in deep space) to validate life-support stability, radiation shielding, and autonomy in long-haul missions.
#   - Mars orbit operations and surface lander demonstrations to finalize surface habitat interfaces, surface power/thermal management, and EVA protocols.
#   - Robotic sample return and pre-deployment of ISRU infrastructure to enable a future crewed Mars surface base.
# - Moon operations scale-up:
#   - Expanded surface habitat capacity; mining and processing facilities for ISRU to sustain longer lunar stays; sub-surface habitats or lava-tube exploration for radiation safety.
#   - Expanded surface mobility and research tasks to collect comparative planetary science data against Mars analogs.
# - Scientific objectives and measurements:
#   - Moon: high-fidelity mapping of PSRs, volatiles, geochemical signatures; long-term radiation dose tracking; testing 3D-printed materials and regolith-based construction methods.
#   - Mars: transit and surface environmental data; ISRU viability for methane or oxygen production; radiation environment characterization for radiation protection design; planetary protection for forward contamination.
# - Transportation and habitat architectures:
#   - Mars transit unit with advanced closed-loop life support and regenerative fuel cell or solar-electric propulsion options; robust lander technology to support surface operations; nuclear or advanced solar power for long Mars missions (depending on policy and safety approvals).
#   - Moon: robust, modular, surface habitats with deeper shielding and life-support redundancy; scalable power generation with large solar arrays and storage.
# - Milestones and technology developments:
#   - Advanced life-support lifecycle demonstrations exceeding 12–18 months in space; validated deep-space propulsion/trajectory optimization; ISRU processing demonstrations on the Moon with sustained outputs; robust EVA suits for Mars-like conditions (suit mobility, debris resistance, thermal control).
# - Launch cadence and estimated costs:
#   - Mars readiness cadence: annual or near-annual robotic and cargo missions to support crewed Mars mission architecture; crewed transit tests in deep space spaced out by ~2–3 years to allow assessments and redesigns.
#   - Lunar cadence: continued rhythm of crew rotations and cargo to test long-duration lunar stays, potentially 6–12 months per crew with on-site production of propellant and supplies.
#   - Phase costs: $50–100B range, factoring in international contributions, with economies of scale from habitat modularization and ISRU replication.
# - Risk assessment and mitigation:
#   - Deep-space radiation risk: enhanced shielding leveraging water/ice, strategic trajectory planning, and active monitoring.
#   - Life-support reliability: advanced redundancy and cross-strapped life-support loops across modules; autonomous repair and provisioning capabilities.
#   - Propulsion and trajectory risk: multiple backup propulsion options (chemical and electric) and alternative mission profiles with abort capabilities to Earth-safe corridors.
#   - Planetary protection: maintain strong planetary protection measures to avoid forward contamination of Mars and Moon environments.
# - International and commercial partnerships:
#   - Expanded collaboration with all major space agencies; joint development of Mars transit architectures; shared ISRU demonstrations; major commercial players in deep-space propulsion and habitat manufacturing.
# - Objective success criteria:
#   - Completed at least one 9–12 month deep-space transit test with sustained life-support and communications operations.
#   - Demonstrated feasibility of ISRU-based propellant or life-support feedstocks on the Moon at scale, with a credible plan for Mars propellant production.
#   - Successful demonstration of Mars landing/deployment systems for future crewed missions; validated EDL and habitat integration for Mars surface dwellings.
#
# Phase 3 (15–20 years; 2040–2045): First crewed Mars mission and sustained, scalable operations
# Objectives
# - Execute a credible, credible crewed Mars mission with long surface stay, complete science objectives, and a robust return plan with validated in-situ resource utilization pipeline.
# - Establish a long-term Moon and cislunar operations culture and infrastructure that can support multiple missions/year and act as a gateway for Mars operations.
# - Produce a sustainable, cost-efficient, and globally collaborative space exploration enterprise.
#
# Mission types and architectures
# - Crewed Mars mission:
#   - A multi-month to year-long Mars expedition (including transit plus surface stay), with a staged approach: long transit, surface mission, and return flight, using ISRU-derived propellants and efficient habitat life-support solutions.
#   - Mars surface base: modular habitat with expanded life-support, power, water and food production, redundancy across systems, and robot-augmented exploration.
# - Moon operations:
#   - A mature, near-continuous outpost capability with frequent crew rotations, ISRU operations producing propellant and oxygen, and extended surface activities employing rovers, surface infrastructure, and sub-surface habitats.
# - Scientific objectives and measurements:
#   - Mars: in-depth geologic and climate data, potential biosignature assessment, long-term habitability metrics, isotopic studies of atmosphere and surface, water/ice distribution mapping, and mission impact on surface geology.
#   - Moon: high-resolution mapping of volatiles, regolith behavior under long-term exposure, and experiments to test durable construction in regolith for future settlements.
# - Transportation and habitat architectures:
#   - Mars transit and surface systems with robust life support, nuclear or large solar power, advanced radiation shielding, and closed-loop food production.
#   - Moon architecture with deep-space redundancy, larger surface base, and ISRU-based propellant generation to sustain rapid mission tempo.
# - Milestones and technology developments:
#   - First crewed Mars mission with long transit and extended surface stay; demonstration of sustained life support across the entire mission lifecycle; proven closed-loop waste and resource cycles; long-term habitat stability and resilience.
#   - On-Moon ISRU scale-up to support sustained operations and act as a testbed for Mars production pipelines.
# - Launch cadence and estimated costs:
#   - This phase represents the peak cost and effort; expect multi-year commitments from space agencies and private partners; total program cost in the hundreds of billions USD over the phase, with substantial international cost-sharing and commercial revenues from lunar operations offsetting part of the Mars program.
# - Risk assessment and mitigation:
#   - Highest Mars mission risk: transit times, radiation exposure, life support fail-states, and abort options. Mitigations include redundant life-support systems, robust radiation shielding, emergency return capabilities, multiple propulsion options, and iterative testing in Earth orbit and cislunar space before Mars transit.
#   - Moon risk: long durations increase wear on life-support and habitat systems; mitigations include modular maintenance, spare parts, telepresence-enabled maintenance, and autonomous repair.
# - International and commercial partnerships:
#   - Global leadership with co-ownership or co-financing for the Mars mission; sustained private sector involvement for propulsion, habitat manufacturing, and in-space resources. Data-sharing frameworks, safety protocols, and export control agreements should be harmonized to enable smooth collaboration.
# - Objective success criteria:
#   - Successfully completed crewed Mars mission with safe arrival, surface operations, and return; life-support viability sustained for the full mission with margins; mission science objectives achieved with robust data products.
#   - Durable cislunar outpost and Moon-based ISRU operations sustaining multiple crews per year and enabling a scalable cadence for Mars support.
#
# Cross-cutting considerations for all phases
# - Science objectives and measurements to standardize:
#   - Moon: water ice mapping, regolith properties, volatiles, exosphere, magnetism, geology and chronology, seismic data, and sample return plans.
#   - Mars: atmosphere, climate cycles, isotopic composition, geology, potential biomarkers, ISRU viability, and long-term habitability metrics.
#   - Measurements should align with international science community standards and be openly shared to maximize scientific return.
# - Risk management approach:
#   - Proactive risk assessment, independent safety reviews, fault-tree analyses, and continuous configuration management.
#   - Redundancy, modular design, and validated interfaces; robust training for crews in contingency procedures.
#   - Insurance-like risk-sharing arrangements with international partners to manage cost risk and liability.
# - Partnerships and governance:
#   - An expanded Artemis-like framework with clear roles for NASA, ESA, JAXA, CSA, and other partners; robust commercial participation for landing systems, life-support modules, habitats, ISRU equipment, and logistics.
#   - Joint science programs and data-sharing agreements; standard interfaces to simplify interoperability and reduce duplication of effort.
#   - Policy alignment for export controls, data rights, and liability protections to encourage sustained investment.
# - Objective success criteria across the program:
#   - Demonstrated technology maturity (TRL 7+) for ISRU, life support, habitat modules, and EVA systems.
#   - Safe and reliable human spaceflight operations in cis-lunar space and on the Moon, with proven long-duration life support and crew safety margins.
#   - Progressive, verifiable Mars mission readiness, culminating in a crewed Mars mission with well-defined return contingencies and mission success metrics.
#   - Scientific milestones met with high-quality, interoperable data products and public access to mission datasets.
#
# Key assumptions and caveats
# - The plan assumes continued political support for international collaboration and a strong role for commercial space companies in lunar and deep-space logistics and infrastructure.
# - Budget timing and scale depend on policy decisions, cost-sharing among international partners, and market conditions for commercial space services.
# - Technological readiness is contingent on sustained investment in ISRU, life-support reliability, radiation shielding innovations, advanced propulsion concepts, in-space manufacturing, and habitat resilience.
# - Contingencies for geopolitical shifts and supply-chain disruptions are incorporated into phased risk management and multipath development strategies.
#
# In summary
# - The Moon-first track leverages near-term capabilities to demonstrate the feasibility of a sustainable outpost, ISRU, and long-duration life support, building a robust platform for Mars exploration.
# - The Mars readiness track iteratively matures deep-space propulsion, life support, EDL for Mars-like environments, and ISRU pipelines to support a credible crewed Mars mission in Phase 3.
# - International and commercial partnerships are central to reducing cost, sharing risk, and accelerating progress.
# - Clear success criteria and phased milestones enable objective evaluation and course corrections as technology, policy, and partnerships evolve.
#
# If you’d like, I can tailor the plan to a specific agency or country’s budget envelope, or convert these phases into a Gantt-style timeline with yearly milestones and a more detailed cost breakout by subsystem and mission type.
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[12], line 13
#      10 model_name = "claude-sonnet-4-5"
#      12 claude = Anthropic()
# ---> 13 response = claude.messages.create(
#      14     model=model_name,
#      15     messages=messages,
#      16     max_tokens=1000,
#      17 )
#      19 display(Markdown(answer))
#      20 competitors.append(model_name)
#
# File ~/Library/CloudStorage/OneDrive-PAX8/Python/Personal_learning/.venv/lib/python3.12/site-packages/anthropic/_utils/_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File ~/Library/CloudStorage/OneDrive-PAX8/Python/Personal_learning/.venv/lib/python3.12/site-packages/anthropic/resources/messages/messages.py:930, in Messages.create(self, max_tokens, messages, model, metadata, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     923 if model in DEPRECATED_MODELS:
#     924     warnings.warn(
#     925         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     926         DeprecationWarning,
#     927         stacklevel=3,
#     928     )
# --> 930 return self._post(
#     931     "/v1/messages",
#     932     body=maybe_transform(
#     933         {
#     934             "max_tokens": max_tokens,
#     935             "messages": messages,
#     936             "model": model,
#     937             "metadata": metadata,
#     938             "service_tier": service_tier,
#     939             "stop_sequences": stop_sequences,
#     940             "stream": stream,
#     941             "system": system,
#     942             "temperature": temperature,
#     943             "thinking": thinking,
#     944             "tool_choice": tool_choice,
#     945             "tools": tools,
#     946             "top_k": top_k,
#     947             "top_p": top_p,
#     948         },
#     949         message_create_params.MessageCreateParamsStreaming
#     950         if stream
#     951         else message_create_params.MessageCreateParamsNonStreaming,
#     952     ),
#     953     options=make_request_options(
#     954         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     955     ),
#     956     cast_to=Message,
#     957     stream=stream or False,
#     958     stream_cls=Stream[RawMessageStreamEvent],
#     959 )
#
# File ~/Library/CloudStorage/OneDrive-PAX8/Python/Personal_learning/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1324, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1310 def post(
#    1311     self,
#    1312     path: str,
#    (...)   1319     stream_cls: type[_StreamT] | None = None,
#    1320 ) -> ResponseT | _StreamT:
#    1321     opts = FinalRequestOptions.construct(
#    1322         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1323     )
# -> 1324     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Library/CloudStorage/OneDrive-PAX8/Python/Personal_learning/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1112, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1109             err.response.read()
#    1111         log.debug("Re-raising status error")
# -> 1112         raise self._make_status_error_from_response(err.response) from None
#    1114     break
#    1116 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'Your credit balance is too low to access the Anthropic API. Please go to Plans & Billing to upgrade or purchase credits.'}, 'request_id': 'req_011CZTSp3oJ7w9R7UEk4zM75'}

# %%
model_name = "claude-haiku-4-5-20251001"

claude = Anthropic()
response = claude.messages.create(
    model=model_name,
    messages=messages,
    max_tokens=1000,
)

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[14], line 4
#       1 model_name = "claude-haiku-4-5-20251001"
#       3 claude = Anthropic()
# ----> 4 response = claude.messages.create(
#       5     model=model_name,
#       6     messages=messages,
#       7     max_tokens=1000,
#       8 )
#      10 display(Markdown(answer))
#      11 competitors.append(model_name)
#
# File ~/Library/CloudStorage/OneDrive-PAX8/Python/Personal_learning/.venv/lib/python3.12/site-packages/anthropic/_utils/_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File ~/Library/CloudStorage/OneDrive-PAX8/Python/Personal_learning/.venv/lib/python3.12/site-packages/anthropic/resources/messages/messages.py:930, in Messages.create(self, max_tokens, messages, model, metadata, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     923 if model in DEPRECATED_MODELS:
#     924     warnings.warn(
#     925         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     926         DeprecationWarning,
#     927         stacklevel=3,
#     928     )
# --> 930 return self._post(
#     931     "/v1/messages",
#     932     body=maybe_transform(
#     933         {
#     934             "max_tokens": max_tokens,
#     935             "messages": messages,
#     936             "model": model,
#     937             "metadata": metadata,
#     938             "service_tier": service_tier,
#     939             "stop_sequences": stop_sequences,
#     940             "stream": stream,
#     941             "system": system,
#     942             "temperature": temperature,
#     943             "thinking": thinking,
#     944             "tool_choice": tool_choice,
#     945             "tools": tools,
#     946             "top_k": top_k,
#     947             "top_p": top_p,
#     948         },
#     949         message_create_params.MessageCreateParamsStreaming
#     950         if stream
#     951         else message_create_params.MessageCreateParamsNonStreaming,
#     952     ),
#     953     options=make_request_options(
#     954         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     955     ),
#     956     cast_to=Message,
#     957     stream=stream or False,
#     958     stream_cls=Stream[RawMessageStreamEvent],
#     959 )
#
# File ~/Library/CloudStorage/OneDrive-PAX8/Python/Personal_learning/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1324, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1310 def post(
#    1311     self,
#    1312     path: str,
#    (...)   1319     stream_cls: type[_StreamT] | None = None,
#    1320 ) -> ResponseT | _StreamT:
#    1321     opts = FinalRequestOptions.construct(
#    1322         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1323     )
# -> 1324     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/Library/CloudStorage/OneDrive-PAX8/Python/Personal_learning/.venv/lib/python3.12/site-packages/anthropic/_base_client.py:1112, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1109             err.response.read()
#    1111         log.debug("Re-raising status error")
# -> 1112         raise self._make_status_error_from_response(err.response) from None
#    1114     break
#    1116 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'Your credit balance is too low to access the Anthropic API. Please go to Plans & Billing to upgrade or purchase credits.'}, 'request_id': 'req_011CZTTEmVDi2J6po46PCLLi'}
